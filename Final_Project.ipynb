# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.read_csv(r'F:\Our Data\California_Houses_Pricing.csv')
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.458  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.458  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.458  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.458  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.458  6.030  80.8  2.5050    1  273
#
#      PATRATIO       B  ISTAT  MEDV
# 0        15.3  396.90   4.98  24.0
# 1        17.8  396.90   9.14  21.6
# ...

# %%
df=pd.read_csv(r'F:\Our Data\California_Houses_Pricing.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PATRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296      15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242      17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242      17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222      18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222      18.7
#
#         B  ISTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 501  0.06263  0.0  11.93     0  0.458  6.593  69.1  2.4786    1  273
# 502  0.04527  0.0  11.93     0  0.458  6.120  76.7  2.2875    1  273
# 503  0.06076  0.0  11.93     0  0.458  6.976  91.0  2.1675    1  273
# 504  0.10959  0.0  11.93     0  0.458  6.794  89.3  2.3889    1  273
# 505  0.04741  0.0  11.93     0  0.458  6.030  80.8  2.5050    1  273
#
#      PATRATIO       B  ISTAT  MEDV
# 501      21.0  391.99   9.67  22.4
# 502      21.0  396.90   9.08  20.6
# 503      21.0  396.90   5.64  23.9
# 504      21.0  393.45   6.48  22.0
# 505      21.0  396.90   7.88  11.9

# %%
df.shape
# Out:
# (506, 14)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PATRATIO', 'B', 'ISTAT', 'MEDV'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CRIM      506 non-null    float64
#  1   ZN        506 non-null    float64
#  2   INDUS     506 non-null    float64
#  3   CHAS      506 non-null    int64
#  4   NOX       506 non-null    float64
#  5   RM        506 non-null    float64
#  6   AGE       506 non-null    float64
#  7   DIS       506 non-null    float64
#  8   RAD       506 non-null    int64
#  9   TAX       506 non-null    int64
#  10  PATRATIO  506 non-null    float64
#  11  B         506 non-null    float64
#  12  ISTAT     506 non-null    float64
#  13  MEDV      506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
#Finding missing values
df.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS        0
# NOX         0
# RM          0
# AGE         0
# DIS         0
# RAD         0
# TAX         0
# PATRATIO    0
# B           0
# ISTAT       0
# MEDV        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#EDA
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.458202    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.003621    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.458000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.458000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.458000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.458000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.538000    8.780000
#
#               AGE         DIS         RAD         TAX    PATRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#Histogram to understand the distribution
for i in df.columns:
    sns.histplot(data=df, x=i)
    plt.show()

# %%
#Boxplot to identify outliers
for i in df.columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
#Scatterplot to understand the relationship
for i in ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PATRATIO', 'B', 'ISTAT']:

    sns.scatterplot(data=df, x=i, y='MEDV')
    plt.show()

# %%
#Correlation with heatmap to interpret correlation and multicollinearity
df.corr()
# Out:
#               CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM      1.000000 -0.200469  0.406583 -0.055892 -0.023363 -0.219247
# ZN       -0.200469  1.000000 -0.533828 -0.042697  0.006587  0.311991
# INDUS     0.406583 -0.533828  1.000000  0.062938 -0.063421 -0.391676
# CHAS     -0.055892 -0.042697  0.062938  1.000000 -0.015191  0.091251
# NOX      -0.023363  0.006587 -0.063421 -0.015191  1.000000  0.026956
# RM       -0.219247  0.311991 -0.391676  0.091251  0.026956  1.000000
# AGE       0.352734 -0.569537  0.644779  0.086518 -0.004636 -0.240265
# DIS      -0.379670  0.664408 -0.708027 -0.099176  0.012825  0.205246
# RAD       0.625505 -0.311948  0.595129 -0.007368 -0.053387 -0.209847
# TAX       0.582764 -0.314563  0.720760 -0.035587 -0.041001 -0.292048
# PATRATIO  0.289946 -0.391679  0.383248 -0.121515 -0.067410 -0.355501
# B        -0.385064  0.175520 -0.356977  0.048788  0.024309  0.128069
# ISTAT     0.455621 -0.412995  0.603800 -0.053929 -0.057231 -0.613808
# ...

# %%
s=df.corr()

# %%
# Visualize the correlation matrix
plt.figure(figsize=(17, 16))
sns.heatmap(s, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation')
plt.show()

# %%
#Solving outliers
def wisker(col):
    q1,q3=np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw

# %%
for i in df.columns:
    lw,uw=wisker(df[i])
    df[i]=np.where(df[i]<lw,lw,df[i])
    df[i]=np.where(df[i]>uw,uw,df[i])

# %%
for i in df.columns:
    sns.boxplot(df[i])
    plt.show()

# %%
#Histogram to understand the distribution after cleaning
for i in df.columns:
    sns.histplot(data=df, x=i)
    plt.show()

# %%
#Scatterplot to understand the relationship after cleaning
for i in ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PATRATIO', 'B', 'ISTAT']:

    sns.scatterplot(data=df, x=i, y='MEDV')
    plt.show()

# %%
# KDE Plot
sns.kdeplot(df['MEDV'], fill=True)
plt.title("KDE Plot of House Prices")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, root_mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
#Feature selection
X = df.drop("MEDV", axis=1)  # independent variables
y = df["MEDV"]               # target variable

# %%
#Scaling features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Train/Test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
#Models Comparison
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd

models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(random_state=42)
}

results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = root_mean_squared_error(y_test, y_pred)
    
    results.append({
        "Model": name,
        "R² Score": round(r2, 3),
        "MAE": round(mae, 2),
        "RMSE": round(rmse, 2)
    })

#Results in a table
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                Model  R² Score   MAE  RMSE
# 0  Linear Regression     0.735  3.00  3.90
# 1      Decision Tree     0.735  2.81  3.90
# 2      Random Forest     0.803  2.24  3.36

# %%
#Feature Selection - Embedded Method (Random Forest Feature Importance)
best_model = RandomForestRegressor(random_state=42)
best_model.fit(X_train, y_train)
importances = pd.Series(best_model.feature_importances_, index=X.columns)
importances.sort_values(ascending=False).plot(kind='bar', title="Feature Importances from Random Forest")
plt.show()

# %%
import joblib
joblib.dump(best_model, "random_forest_model.pkl")
# Out:
# ['random_forest_model.pkl']

# %%
#Interpret Results
#Predict the price of a house in California based on different features of the house and its neighborhood.


#Q: What is the goal of this dataset?
#A: To predict the median value of owner-occupied homes (in $1000s) based on housing and neighborhood features.

#Q: What type of machine learning task is this?
#A: It’s a regression task.

#Q: Which features are most influential in predicting house prices?
#A: ISTAT (% low-income population), RM (number of rooms), Dis (Employment Places), Age,  PTRATIO (student-teacher ratio), and TAX (property tax rate).

#Q: What algorithm gave the best performance in your project?
#A: Random Forest Regressor, based on highest R² and lowest RMSE/MAE.

#Q: Why did you choose to simplify the app inputs to only 4 features?
#A: To make the app user-friendly and focus on the most impactful predictors.

#The KDE plot of house prices (MEDV) reveals a right-skewed distribution, with most home values concentrated around $20,000. Few properties exceed $40,000, indicating some high-value outliers. The distribution helps understand the overall pricing trends in the dataset.
#Based on the evaluation metrics, the Random Forest Regressor achieved the best performance, with the highest R² Score (0.803), the lowest MAE (2.24), and the lowest RMSE (3.36). Therefore, it was selected as the final model for deployment and analysis.
#MEDV has a negative strong relationship with ISTAT, a positive moderate relationship with RM, and a negative moderate relationship with PATRATIO.
